# %%
# Read empData.csv
emp_df = spark.read.csv(
    "/Volumes/workspace/default/assignment/empData.csv",
    header=True,
    inferSchema=True
)

# Read Big Sales.csv
sales_df = spark.read.csv(
    "/Volumes/workspace/default/assignment/Big Sales.csv",
    header=True,
    inferSchema=True
)


print("Employee Data")
display(emp_df)

print("Sales Data - First 5 Rows")
display(sales_df.limit(5))
# Out:
# Employee Data
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th><th>address</th></tr></thead><tbody><tr><td>1</td><td>manish</td><td>10000</td><td>india</td></tr><tr><td>2</td><td>rani</td><td>20000</td><td>usa</td></tr><tr><td>3</td><td>rinku</td><td>55000</td><td>uk</td></tr><tr><td>4</td><td>neha</td><td>12000</td><td>usa</td></tr><tr><td>5</td><td>sneha</td><td>20000</td><td>uk</td></tr><tr><td>6</td><td>rahul</td><td>30000</td><td>india</td></tr></tbody></table></div>
# Sales Data - First 5 Rows
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
# ...
